# %% [markdown]
# <a href="https://colab.research.google.com/github/JollyJiant/Data-or-No-Deal/blob/main/Data_or_No_Deal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data or No Deal
# ## Exploring decision-making under uncertainty using data from the game show "Deal or No Deal"
#
# ### Contestant Profile
# * How are contestant features associated with stopping behavior and winnings?
# * Do contestants cluster into distinct play-style or risk-behavior archetypes?
# ### Banker Behavior
# * How can we model the banker's offers?
# * Are offers influenced by game state, contestant profile, or both?
# ### Game Strategy
# * What makes a game state "risky" and can that be quantified?
# * When should players accept or reject the banker's deal?
# * Does the data suggest any effective style of play?
# ### Other ideas
# * Feature engineering: estimated risk tolerance, board volatility (distribution of remaining case values).

# %%
import pandas as pd

# %%
dealorno = pd.read_excel('dealorno.xlsx')
dealorno.sample(5)
# Out:
#     ID Number Broadcast Date     Name Education Gender  Age  Stop Round  \
# 201    US.026     2006-04-05     Hans         L      M   30           6
# 88     US.011     2006-03-06      Kim         L      F   43           7
# 75     US.009     2006-02-27   Cheryl         H      F   40          10
# 290    US.039     2006-05-10  Shirley         L      F   42           7
# 231    US.031     2006-04-17   Thorpe         L      M   34           7
#
#      Amount Won  ROUND Deal / No Deal  ...  25000  50000  75000  100000  \
# 201       45000      3             ND  ...      0      0      1       0
# 88        50000      4             ND  ...      0      1      0       0
# 75            5      9             ND  ...      0      0      0       0
# 290       98000      2             ND  ...      0      1      1       1
# 231      464000      2             ND  ...      0      1      0       1
#
#      200000  300000  400000  500000  750000  1000000
# ...
